# %% [markdown]
# # Apriori

# %% [markdown]
# ## Importing the libraries

# %%
# !pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=2f2fcdf2183fffbb8bf9f004621b9dd38d512e3464dd5313ed49d5cf424c332a
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Training the Apriori model on the dataset

# %%
dataset=pd.read_csv('Market_Basket_Optimisation.csv', header=None)
transactions=[]
for i in range(1,7501):
  transactions.append([str(dataset.values[i,j]) for j in range(1,20)])

# %% [markdown]
# ## Visualising the results

# %%
from apyori import apriori
rules=apriori(transactions=transactions,min_support=0.003,min_confidence=0.2,min_lift=3,min_length=2,max_length=2)

# %% [markdown]
# ### Displaying the first results coming directly from the output of the apriori function

# %%
results=list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'bacon', 'spaghetti'}), support=0.0030666666666666668, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'spaghetti'}), confidence=0.38983050847457634, lift=3.071143711721977)]),
#  RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004266666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.28571428571428575, lift=5.277973258268825)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.004666666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.2573529411764706, lift=4.270236855804269)]),
# ...

# %% [markdown]
# ### Putting the results well organised into a Pandas DataFrame

# %%
def inspects(results):
  lhs = [tuple(result[2][0][0])[0] for result in results]
  rhs = [tuple(result[2][0][1])[0] for result in results]
  support=[result[1] for result in results]
  confidance=[result[2][0][2] for result in results]
  lifts=[result[2][0][3] for result in results]
  return list(zip(lhs,rhs,support,confidance,lifts))
resultinDataFrame=pd.DataFrame(inspects(results), columns=['Left Hand Side','Right Hand Side','Support','Confidance','Lift'])

# %% [markdown]
# ### Displaying the results non sorted

# %%
resultinDataFrame
# Out:
#           Left Hand Side    Right Hand Side   Support  Confidance      Lift
# 0                  bacon          spaghetti  0.003067    0.389831  3.071144
# 1            light cream            chicken  0.004267    0.285714  5.277973
# 2   mushroom cream sauce           escalope  0.004667    0.257353  4.270237
# 3                  pasta           escalope  0.003200    0.226415  3.756888
# 4          fromage blanc              honey  0.003200    0.272727  6.236142
# 5      frozen vegetables        ground beef  0.010267    0.225146  3.253558
# 6        parmesan cheese  frozen vegetables  0.003067    0.234694  5.146796
# 7                 shrimp  frozen vegetables  0.006267    0.222749  4.884842
# 8      frozen vegetables           tomatoes  0.009200    0.201754  5.027103
# 9          grated cheese        ground beef  0.003333    0.250000  3.612717
# 10         grated cheese          spaghetti  0.005600    0.420000  3.308824
# ...

# %% [markdown]
# ### Displaying the results sorted by descending lifts

# %%
resultinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#           Left Hand Side    Right Hand Side   Support  Confidance      Lift
# 4          fromage blanc              honey  0.003200    0.272727  6.236142
# 1            light cream            chicken  0.004267    0.285714  5.277973
# 6        parmesan cheese  frozen vegetables  0.003067    0.234694  5.146796
# 8      frozen vegetables           tomatoes  0.009200    0.201754  5.027103
# 7                 shrimp  frozen vegetables  0.006267    0.222749  4.884842
# 16          tomato sauce        ground beef  0.003600    0.329268  4.758212
# 11         herb & pepper        ground beef  0.006000    0.323741  4.678338
# 22     whole wheat pasta          olive oil  0.004400    0.261905  4.610999
# 2   mushroom cream sauce           escalope  0.004667    0.257353  4.270237
# 26          tomato sauce          spaghetti  0.005600    0.512195  4.035151
