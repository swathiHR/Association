# %% [markdown]
# # Eclat

# %% [markdown]
# ## Importing the libraries

# %%
# !pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=baf24f3b82ed65571c2741d7488d40f5837a6e6aa4cd0e99b64bd577aff9e3f7
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Market_Basket_Optimisation.csv',header=None)
transactions = []
for i in range(1,7501):
  transactions.append([str(dataset.values[i,j]) for j in range(0,20)])

# %% [markdown]
# ## Training the Eclat model on the dataset

# %%
from apyori import apriori
rules=apriori(transactions=transactions,min_support=0.002,min_confidance=0.2,min_lift=3,min_length=2,max_length=2)

# %% [markdown]
# ## Visualising the results

# %% [markdown]
# ### Displaying the first results coming directly from the output of the apriori function

# %%
results=list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'barbecue sauce', 'turkey'}), support=0.002533333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset({'barbecue sauce'}), items_add=frozenset({'turkey'}), confidence=0.2345679012345679, lift=3.7510858406380794), OrderedStatistic(items_base=frozenset({'turkey'}), items_add=frozenset({'barbecue sauce'}), confidence=0.04051172707889126, lift=3.7510858406380794)]),
#  RelationRecord(items=frozenset({'cottage cheese', 'brownies'}), support=0.0034666666666666665, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'cottage cheese'}), confidence=0.10276679841897234, lift=3.2384495300096323), OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'brownies'}), confidence=0.10924369747899158, lift=3.2384495300096323)]),
# ...

# %% [markdown]
# ### Putting the results well organised into a Pandas DataFrame

# %%
def inspects(results):
  lhs = [tuple(result[2][0][0])[0] for result in results]
  rhs = [tuple(result[2][0][1])[0] for result in results]
  support=[result[1] for result in results]
  return list(zip(lhs,rhs,support))
resultinDataFrame=pd.DataFrame(inspects(results), columns=['Product 1','Product2','Support'])

# %%
resultinDataFrame
# Out:
#                Product 1              Product2   Support
# 0         barbecue sauce                turkey  0.002533
# 1               brownies        cottage cheese  0.003467
# 2                carrots                salmon  0.002000
# 3                chicken  extra dark chocolate  0.002800
# 4                chicken           light cream  0.004533
# 5                chicken             magazines  0.002000
# 6                cookies               shallot  0.002000
# 7            cooking oil           light cream  0.002800
# 8               escalope  mushroom cream sauce  0.005733
# 9               escalope                 pasta  0.005867
# 10  extra dark chocolate             olive oil  0.002667
# 11           french wine            fresh tuna  0.002533
# 12           fresh bread          tomato juice  0.004267
# 13            fresh tuna         fromage blanc  0.002400
# 14            fresh tuna                 honey  0.004000
# ...

# %% [markdown]
# ### Displaying the results sorted by descending supports

# %%
resultinDataFrame.nlargest(n=10,columns='Support')
# Out:
#       Product 1              Product2   Support
# 17  ground beef         herb & pepper  0.016000
# 26    olive oil     whole wheat pasta  0.008000
# 9      escalope                 pasta  0.005867
# 8      escalope  mushroom cream sauce  0.005733
# 18  ground beef          tomato sauce  0.005333
# 28        pasta                shrimp  0.005067
# 4       chicken           light cream  0.004533
# 12  fresh bread          tomato juice  0.004267
# 14   fresh tuna                 honey  0.004000
# 1      brownies        cottage cheese  0.003467
